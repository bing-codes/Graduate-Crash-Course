# %% [markdown]
# # Day 2 -- Python for Researchers
#
# ## Today's Goals:
#    * Use the pandas library
#    * Understand what a dataframe and series are
#    * Learn how to execute basic data cleaning
#    * Learn some key functions for data analysis

# %% [markdown]
# **Introduction to Pandas**
#
# Pandas is the industry standard data analysis library. It lets us convert raw datasets (typically a .csv file) into something called a *dataframe*. A dataframe looks like a spreadsheet, but is actually optimized to allow you to handle large datasets quickly and efficiently. We can use pandas to clean, analyze, and even visualize our data.
#
# In pandas you can work with two kinds of objects -- a dataframe, or a 2D array (something with rows and columns) or a series, a 1D array (or just a  singular column). Both of these objects comes with different built-in functions that we will explore throughout today's lesson.
#
# Pandas is a really powerful tool for researchers. Oftentimes, the way you really learn to master it is by looking at examples and reading documentation. They have a ["10 Minutes to Pandas"](https://pandas.pydata.org/docs/user_guide/10min.html) guide we recommend you return to after this week. You can also reference the [official documentation](https://pandas.pydata.org/docs/reference/frame.html) or the more simple, but less detailed, [w3schools documentation](https://www.w3schools.com/python/pandas/pandas_dataframes.asp).

# %% [markdown]
# #### Section 1: Our first dataset
#
# To start our exploration of pandas, we're going to use a Film Permits dataset from the [NYC Open Data site](https://data.cityofnewyork.us/City-Government/Film-Permits/tg4x-b46p/about_data). That dataset is already in our Day 3 folder. Please note: when you gather a dataset online, it typically comes with it's own internal logic -- especially goverment datasets -- so you will want to study any documentation they provide to better undersatnd your data.
#
# In order to use pandas, you always have to import it. The common way to do this is to *import pandas as pd* -- pd just is a shorter amout of letters to type in.
#
# We are using a csv file, that stands for "comma separated values" and is an agnostic file type. You could also load an excel spreadsheet with the function pd.read_excel('file.xlsx'). Learn more about the different types of files you can use pandas with in the [input/output documentation](https://pandas.pydata.org/docs/reference/io.html).
#
# To create your dataframe, you run the code below. Our dataframe is being stored in the variable permits_df.

# %%
import pandas as pd
permits_df = pd.read_csv("Film_Permits_2025.csv")

#Take a second to study the output, what can we learn from it?
permits_df
# Out:
#        EventID                      EventType           StartDateTime  \
# 0       753784  Theater Load in and Load Outs  12/24/2023 12:01:00 AM
# 1       752706                Shooting Permit  12/13/2023 06:00:00 AM
# 2       753230                Shooting Permit  12/18/2023 07:00:00 AM
# 3       752951                Shooting Permit  12/14/2023 07:00:00 AM
# 4       752181                Shooting Permit  12/13/2023 06:00:00 AM
# ...        ...                            ...                     ...
# 11576   835577                Shooting Permit  02/15/2025 12:00:00 AM
# 11577   834355  Theater Load in and Load Outs  02/15/2025 12:01:00 AM
# 11578   834236  Theater Load in and Load Outs  02/15/2025 12:01:00 AM
# 11579   834362  Theater Load in and Load Outs  02/16/2025 12:01:00 AM
# 11580   835038                Shooting Permit  02/16/2025 06:00:00 AM
#
#                   EndDateTime               EnteredOn  \
# 0      12/31/2023 11:59:00 PM  12/18/2023 12:59:21 PM
# 1      12/13/2023 08:00:00 PM  12/06/2023 09:01:38 AM
# 2      12/18/2023 11:59:00 PM  12/12/2023 10:09:19 AM
# 3      12/14/2023 09:00:00 PM  12/08/2023 09:29:50 AM
# 4      12/13/2023 11:59:00 PM  12/01/2023 09:38:19 AM
# ...                       ...                     ...
# 11576  02/15/2025 01:00:00 PM  02/14/2025 09:47:11 AM
# 11577  02/15/2025 11:59:00 PM  02/04/2025 01:57:53 PM
# 11578  02/16/2025 06:00:00 AM  02/03/2025 04:23:45 PM
# 11579  02/17/2025 06:00:00 AM  02/04/2025 02:09:39 PM
# 11580  02/16/2025 10:00:00 PM  02/10/2025 03:05:07 PM
#
#                                    EventAgency  \
# 0      Mayor's Office of Media & Entertainment
# 1      Mayor's Office of Media & Entertainment
# 2      Mayor's Office of Media & Entertainment
# 3      Mayor's Office of Media & Entertainment
# 4      Mayor's Office of Media & Entertainment
# ...                                        ...
# 11576  Mayor's Office of Media & Entertainment
# 11577  Mayor's Office of Media & Entertainment
# 11578  Mayor's Office of Media & Entertainment
# 11579  Mayor's Office of Media & Entertainment
# 11580  Mayor's Office of Media & Entertainment
#
#                                              ParkingHeld    Borough  \
# 0      WEST   62 STREET between COLUMBUS AVENUE and A...  Manhattan
# 1      HUDSON STREET between MORTON STREET and BARROW...  Manhattan
# 2      ROSE FEISS BOULEVARD between EAST  139 STREET ...      Bronx
# 3      ATLANTIC AVENUE between WASHINGTON AVENUE and ...   Brooklyn
# 4      GRAND AVENUE between 64 STREET and FLUSHING AV...     Queens
# ...                                                  ...        ...
# 11576     WEST   48 STREET between 6 AVENUE and 7 AVENUE  Manhattan
# 11577  EAST   11 STREET between 3 AVENUE and 4 AVENUE...  Manhattan
# 11578  DEKALB AVENUE between FLATBUSH AVENUE EXTENSIO...   Brooklyn
# 11579  EAST   11 STREET between 3 AVENUE and 4 AVENUE...  Manhattan
# 11580  EAST  136 STREET between BRUCKNER BOULEVARD an...      Bronx
#
#       CommunityBoard(s) PolicePrecinct(s)    Category  SubCategoryName  \
# 0                     7                20     Theater          Theater
# 1               1, 2, 3   5, 6, 7, 84, 90        Film          Feature
# 2                     1                40  Television  Episodic series
# 3                     8                77  Television  Episodic series
# 4                  1, 5           104, 94  Television  Episodic series
# ...                 ...               ...         ...              ...
# 11576                 5                18  Television             News
# 11577             11, 3             23, 9     Theater          Theater
# 11578                 2                88     Theater          Theater
# 11579             11, 3             23, 9     Theater          Theater
# 11580                 1                40        Film            Short
#
#                         Country                         ZipCode(s)
# 0      United States of America                              10023
# 1      United States of America  10002, 10014, 10038, 11201, 11211
# 2      United States of America                              10454
# 3      United States of America                              11238
# 4      United States of America                       11222, 11378
# ...                         ...                                ...
# 11576  United States of America                       10036, 10105
# 11577  United States of America                       10003, 10029
# 11578  United States of America                              11201
# 11579  United States of America                       10003, 10029
# 11580  United States of America                              10454
#
# [11581 rows x 14 columns]

# %% [markdown]
# **Learning about our dataset**
#
# We're going to use four techniques to learn about our dataset:
#
#   * info() -- tells you how many rows and columns there are; the names of each column; the different kinds of datatype contained in the columns; and how many non-null values there are in each column
#   * head() -- shows by default the top five rows, you can add an optional parameter (a number) to show more
#   * tail() -- same as head(), except it shows you the bottom rows
#   * .dtypes -- tells you what each column's data type is

# %%
permits_df.info()

# %%
permits_df.head()

# %%
permits_df.tail()

# %% [markdown]
# Note that there are seven datatypes in pandas, some of which correspond to the datatypes in Python:
#
# * object (equivalent to a Python string - could be a combination of letters, numbers, and special characters)
# * int64 (integer)
# * float64 (floating number aka decimal)
# * bool (Boolean, True/False values)
# * datetime64 (date and time values)
# * timedelta[ns] (differences between two values)
# * category (finite list of text values, corresponds to categorical variables in statistics)
#
# It's important to know what types of data you are manipulating, because they all come with unique abilities and limitations.
#
# What kind of datatypes does our dataframe contain?

# %%
permits_df.dtypes
# Out:
# EventID               int64
# EventType            object
# StartDateTime        object
# EndDateTime          object
# EnteredOn            object
# EventAgency          object
# ParkingHeld          object
# Borough              object
# CommunityBoard(s)    object
# PolicePrecinct(s)    object
# Category             object
# SubCategoryName      object
# Country              object
# ZipCode(s)           object
# dtype: object

# %% [markdown]
# We can also access specific information in our dataframe. The most frequent way you will do this is to isolate a column.
#
# The preferred syntax for this is to use brackets and input the column name as strings. You can isolate only one at a time,
# or isolate multiple by writing them in a list.

# %%
#isolating one column
permits_df["Borough"]

# %%
#isolating multiple columns
permits_df[["EventID", "Borough", "Category"]]

# %% [markdown]
# If you want to isolate very specific information, you can use .iloc and .loc
#
#  * You use .loc when dealing with column names (labels), e.g., below isolates the rows in the EventType column that are "Theater Load in and Load Outs"
#  * You use .iloc when you want to index a specific row and column (iloc stands of “integer location”),
#    e.g., below isolates the first five entries in the EventAgency column

# %%
#example of loc

permits_df.loc[permits_df["EventType"] == "Theater Load in and Load Outs"]

# %%
#example of iloc

permits_df.iloc[:5, 5]
# Out:
# 0    Mayor's Office of Media & Entertainment
# 1    Mayor's Office of Media & Entertainment
# 2    Mayor's Office of Media & Entertainment
# 3    Mayor's Office of Media & Entertainment
# 4    Mayor's Office of Media & Entertainment
# Name: EventAgency, dtype: object

# %% [markdown]
# **Preparing our dataset for analysis**
#
# Here's our research question: *How many of each film permit type was distributed in each borough?* Because this dataset was produced by NYC, it's pretty clean. We just want to drop the columns that don't help us answer our research question so that we can save memory. It's not a huge dataset, so this isn't necessary, but is useful to know how to do.
#
# Here are all our columns (I turned them into a list for easy reading).

# %%
list(permits_df.columns)

# %% [markdown]
# We probably don't care about a number of those partiular columns, so let's drop them.
#
# It's best practice to make a copy of your dataframe before you start changing it, so we'll start with that:

# %%
permits_df_copy = permits_df.copy()

# %% [markdown]
# Then we can drop several of those columns using drop(). Here's some info about what we're doing:
#  * drop() elimates columns
#  * You have to tell it what column names you want to drop, this can be passed as a list
#  * You also want to explicitly tell pandas that you are dropping columns using the columns keyword (alternative names: keyword argument, kwarg, parameter)
#  * We are storing the changes in the same variable - this is called **reassigning**
#
# I've dropped two columns below, try adding another column name to the list that we don't need!

# %%
#reassigning - or saving over - our permits_df_copy variable 
permits_df_copy = permits_df_copy.drop(columns=["CommunityBoard(s)", "PolicePrecinct(s)"])

# %% [markdown]
# **Doing the analysis**
#
# We need to take the next four steps to answer our RQ:
#   * isolate the two columns that have our information (EventType and Borough)
#   * use value_counts() which helps us aggregate values in columns
#   * convert this into it's own dataframe using reset_index()
#   * sort the columns for easier viewing using sort_values()
#
#
# Warning:
# Each of these actions is CHANGING data! If you run them multiple times you may get errors. When in doubt, you can go back up to the previous cell and re-establish the permits_df_copy variable to start with a clean dataframe.

# %%
#isolate our two columns:

rq_df = permits_df_copy[["EventType", "Borough"]]
rq_df
# Out:
#                            EventType    Borough
# 0      Theater Load in and Load Outs  Manhattan
# 1                    Shooting Permit  Manhattan
# 2                    Shooting Permit      Bronx
# 3                    Shooting Permit   Brooklyn
# 4                    Shooting Permit     Queens
# ...                              ...        ...
# 11576                Shooting Permit  Manhattan
# 11577  Theater Load in and Load Outs  Manhattan
# 11578  Theater Load in and Load Outs   Brooklyn
# 11579  Theater Load in and Load Outs  Manhattan
# 11580                Shooting Permit      Bronx
#
# [11581 rows x 2 columns]

# %%
#count the values
#this output LOOKS like it is a dataframe, but it's actually a series

rq_df = rq_df.value_counts()
rq_df

#You can always use the type() in Python if you are unsure about what kind of data you're dealing with 
#type(rq_df)
# Out:
# EventType                      Borough
# Shooting Permit                Manhattan        3945
#                                Brooklyn         3176
# Theater Load in and Load Outs  Manhattan        1648
# Shooting Permit                Queens           1535
# Theater Load in and Load Outs  Brooklyn          560
# Shooting Permit                Bronx             331
# Rigging Permit                 Manhattan         132
#                                Brooklyn           74
# Shooting Permit                Staten Island      63
# DCAS Prep/Shoot/Wrap Permit    Manhattan          50
# Rigging Permit                 Queens             28
#                                Bronx              17
# DCAS Prep/Shoot/Wrap Permit    Bronx               6
#                                Brooklyn            5
# Theater Load in and Load Outs  Bronx               5
# DCAS Prep/Shoot/Wrap Permit    Queens              3
# Rigging Permit                 Staten Island       1
# DCAS Prep/Shoot/Wrap Permit    Staten Island       1
# Theater Load in and Load Outs  Queens              1
# Name: count, dtype: int64

# %%
#reset the index to transform it into a dataframe

rq_df = rq_df.reset_index()
rq_df.columns = ["Event", "Borough", "Count"] #names columns
rq_df
# Out:
#                             Event        Borough  Count
# 0                 Shooting Permit      Manhattan   3945
# 1                 Shooting Permit       Brooklyn   3176
# 2   Theater Load in and Load Outs      Manhattan   1648
# 3                 Shooting Permit         Queens   1535
# 4   Theater Load in and Load Outs       Brooklyn    560
# 5                 Shooting Permit          Bronx    331
# 6                  Rigging Permit      Manhattan    132
# 7                  Rigging Permit       Brooklyn     74
# 8                 Shooting Permit  Staten Island     63
# 9     DCAS Prep/Shoot/Wrap Permit      Manhattan     50
# 10                 Rigging Permit         Queens     28
# 11                 Rigging Permit          Bronx     17
# 12    DCAS Prep/Shoot/Wrap Permit          Bronx      6
# 13    DCAS Prep/Shoot/Wrap Permit       Brooklyn      5
# 14  Theater Load in and Load Outs          Bronx      5
# 15    DCAS Prep/Shoot/Wrap Permit         Queens      3
# 16                 Rigging Permit  Staten Island      1
# 17    DCAS Prep/Shoot/Wrap Permit  Staten Island      1
# 18  Theater Load in and Load Outs         Queens      1

# %%
rq_df.sort_values("Event", inplace = True, ascending = False) 
rq_df
# Out:
#                             Event        Borough  Count
# 18  Theater Load in and Load Outs         Queens      1
# 2   Theater Load in and Load Outs      Manhattan   1648
# 14  Theater Load in and Load Outs          Bronx      5
# 4   Theater Load in and Load Outs       Brooklyn    560
# 8                 Shooting Permit  Staten Island     63
# 1                 Shooting Permit       Brooklyn   3176
# 0                 Shooting Permit      Manhattan   3945
# 5                 Shooting Permit          Bronx    331
# 3                 Shooting Permit         Queens   1535
# 7                  Rigging Permit       Brooklyn     74
# 6                  Rigging Permit      Manhattan    132
# 10                 Rigging Permit         Queens     28
# 11                 Rigging Permit          Bronx     17
# 16                 Rigging Permit  Staten Island      1
# 12    DCAS Prep/Shoot/Wrap Permit          Bronx      6
# 13    DCAS Prep/Shoot/Wrap Permit       Brooklyn      5
# 15    DCAS Prep/Shoot/Wrap Permit         Queens      3
# 17    DCAS Prep/Shoot/Wrap Permit  Staten Island      1
# 9     DCAS Prep/Shoot/Wrap Permit      Manhattan     50

# %% [markdown]
# It's your turn!
#
# Try to answer this research question: *Which borough distributed the most permits?*
#
# The best way to think about how to answer that question is to consider:
#   1. What information are you trying to access?
#   2. What rows or columns *have* that information?
#   3. What tools do you have in the pandas library that can accomplish that task?

# %%
#your answer

permits_df["Borough"].value_counts()
# Out:
# Borough
# Manhattan        5775
# Brooklyn         3815
# Queens           1567
# Bronx             359
# Staten Island      65
# Name: count, dtype: int64

# %% [markdown]
# #### Section 2: Our Second Dataset
#
# You can find our second dataset [here](https://drive.google.com/file/d/1RgcK9VPCIxVMDZabQAJhWCp7z0LD_Im3/view?usp=sharing). It has information about the top 1000 ranking movies on IMDB. Please download that and bring it into your working directory.
#
# Oftentimes online movie ratings have a recency bias -- that is, the more recently a movie was made, the more likely it is to have a high review because people have just seen it. That leads us to ask a few questions: *How many different years are represented in this dataset? Which years have the highest number of movies associated with them? And of those years, are most of them after 2000?*

# %%
import pandas as pd

film_df = pd.read_csv("imdb_top_1000.csv")
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# **Cleaning data three different ways**
#
# There's actually an error in our dataset that is going to create an issue for us. Do you notice that the Release_Year column is an object datatype? You wouldn't expect that because it should *in theory* all be numbers. What I found is that one singular row has the string "PG" in it instead of a year.

# %%
#proof that we have one singular string in our Released_Year column

for i in film_df["Released_Year"].to_list():
    if i.isalpha():
        print(i)
# Out:
# PG

# %% [markdown]
# *Using loc[]*
#
# I can use loc[] (which we learned above) to isolate this row because I know the value (pandas calls this a label). Remember: loc[] lets us access rows and columns by the label! This then shows me the index. I can then use the index to drop that row from my dataset.

# %%
film_df.loc[film_df["Released_Year"] == "PG"]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
#notice that we only have 999 rows now compared to before!

film_df_copy = film_df.drop(966)
film_df_copy.info()

# %% [markdown]
# *Using isin()*
#
# This looks for a list of values in the row, and if they ARE present, it drops them. Notice that we're isolating the appropriate column, using .isin() to pass a list of values (in this case, we only had one value!), and only keep the rows that do NOT have those values in them.

# %%
film_df_copy_2 = film_df[film_df["Released_Year"].isin(["PG"]) == False]
#alternative line film_df_copy_2 = film_df[~film_df["Released_Year"].isin(["PG"])]
film_df_copy_2.info()

# %% [markdown]
# *Flexible solution with notna()*
#
# There is an inherent limitation to the previous two solutions: if we have more than one row with alphabetical characters, and those are different, it becomes quite tedious! This is called *hard coding*, where you create a very inflexible bit of code that only works for one singluar situation. Generally, you want to build flexible code that can handle multiple situations.
#
# Thus, the better, and more flexible, method would be to simply drop the rows if they contained alphabetical characters. This produces the same effect as above, but would work with ANY row that contained alphabetical characters.
#
# Here's a breakdown:
#   * We isolated the Released_Year column and try to convert each value to a number using to_numeric(). If that value cannot be converted, it becomes NaN. This means Not A Number and is pandas version of "None" or "Null"
#   * the function notna() in pandas returns a True Boolean for any value that isn't NAN
#   * this construction automatically keeps only the rows where notna() returned a True Boolean

# %%
film_df = film_df[pd.to_numeric(film_df["Released_Year"], errors="coerce").notna()]
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    999 non-null    object
#  1   Series_Title   999 non-null    object
#  2   Released_Year  999 non-null    object
#  3   Certificate    898 non-null    object
#  4   Runtime        999 non-null    object
#  5   Genre          999 non-null    object
#  6   IMDB_Rating    999 non-null    float64
#  7   Overview       999 non-null    object
#  8   Meta_score     842 non-null    float64
#  9   Director       999 non-null    object
#  10  Star1          999 non-null    object
#  11  Star2          999 non-null    object
#  12  Star3          999 non-null    object
#  13  Star4          999 non-null    object
#  14  No_of_Votes    999 non-null    int64
#  15  Gross          830 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 132.7+ KB

# %% [markdown]
# Importantly, that column is STILL listed as an object datatype, we have to take the final step to convert it into an int64 datatype, no matter which of the three options above we chose to do.

# %%
#resetting the column to be read as integers (numbers)
film_df = film_df.astype({"Released_Year": "int64"})

# %% [markdown]
# Now we can answer our RQ! It turns out that there are 100 years of movies represented in this dataset, but 17 out of the 20 top-rated movies come from after 2000. So I would definitely say it has a recency bias!
#
# Below we use a concept called *boolean masking*. It's super useful in pandas!
#   * It issentially is a way we can overlay (or mask) or data with boolean values.
#   * You just need to establish a condition, and when you pass that condition to your dataframe, it will automatically drop all of the False boolean values

# %%
#creating new dataframe
year_aggregate = film_df["Released_Year"].value_counts()
year_aggregate = year_aggregate.reset_index()
year_aggregate.columns = ["Release Year", "Number of Movies"]

year_aggregate
# Out:
#     Release Year  Number of Movies
# 0           2014                32
# 1           2004                31
# 2           2009                29
# 3           2013                28
# 4           2016                28
# ..           ...               ...
# 94          1930                 1
# 95          1921                 1
# 96          1936                 1
# 97          1922                 1
# 98          1943                 1
#
# [99 rows x 2 columns]

# %%
#isolate top 20
top_20 = year_aggregate.head(20)
top_20
# Out:
#     Release Year  Number of Movies
# 0           2014                32
# 1           2004                31
# 2           2009                29
# 3           2013                28
# 4           2016                28
# 5           2001                27
# 6           2007                26
# 7           2006                26
# 8           2015                25
# 9           2012                24
# 10          2019                23
# 11          2010                23
# 12          1993                23
# 13          2003                22
# 14          2017                22
# 15          2008                21
# 16          2002                19
# 17          1997                19
# 18          1995                19
# 19          2018                19

# %%
#boolean masking
condition_1 = top_20["Release Year"] >= 2000
final_df = top_20[condition_1]
final_df.count()
# Out:
# Release Year        17
# Number of Movies    17
# dtype: int64

# %% [markdown]
# Now that we've done ALL that, let's also evaluate which release year has the highest rating on average to see if there's a bias that way. There doesn't seem to be one!
#
# Here's what groupby() does:
#   * It groups rows in a dataframe based on the values of one or more columns. In this case, we're grouping the release year column by the IMDB rating.
#   * Notice the syntax, we are grouping the rows in the Released_Year column and we're taking the mean (average) IMDB rating for each.

# %%
avg_rating = film_df.groupby("Released_Year")["IMDB_Rating"].mean()

# %%
avg_rating_df = avg_rating.reset_index()
avg_rating_df.columns = ["Year", "Avg_Rating"]

avg_rating_df.sort_values("Avg_Rating", inplace = True, ascending = False) 
avg_rating_df.head(20)
# Out:
#     Year  Avg_Rating
# 14  1936    8.500000
# 1   1921    8.300000
# 35  1957    8.277778
# 72  1994    8.238462
# 20  1942    8.233333
# 9   1931    8.200000
# 3   1924    8.200000
# 6   1927    8.200000
# 32  1954    8.166667
# 19  1941    8.150000
# 28  1950    8.140000
# 98  2020    8.133333
# 36  1958    8.100000
# 15  1937    8.100000
# 0   1920    8.100000
# 4   1925    8.100000
# 5   1926    8.100000
# 7   1928    8.100000
# 53  1975    8.088889
# 50  1972    8.087500

# %% [markdown]
# If you understand this recency bias, you could isolate only the rows that come from before 2000 and do your analysis excluding more recent movies. We can use loc[] or boolean masking to do this, it accomplishes the same thing! Generally loc[] is the preferred method because it's more precise overall, but it's useful to know multiple means of doing something.

# %%
film_df.loc[film_df["Released_Year"] < 2000]
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A  142 min
# 1               The Godfather           1972           A  175 min
# 3      The Godfather: Part II           1974           A  202 min
# 4                12 Angry Men           1957           U   96 min
# 6                Pulp Fiction           1994           A  154 min
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's           1961           A  115 min
# 996                     Giant           1956           G  201 min
# 997     From Here to Eternity           1953      Passed  118 min
# 998                  Lifeboat           1944         NaN   97 min
# 999              The 39 Steps           1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# 6                Crime, Drama          8.9
# ..                        ...          ...
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# 6    The lives of two mob hitmen, a boxer, a gangst...        94.0
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# 6       Quentin Tarantino      John Travolta        Uma Thurman
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#                  Star3           Star4  No_of_Votes        Gross
# 0           Bob Gunton  William Sadler      2343110   28,341,469
# 1           James Caan    Diane Keaton      1620367  134,966,411
# 3        Robert Duvall    Diane Keaton      1129952   57,300,000
# 4        Martin Balsam    John Fiedler       689845    4,360,000
# 6    Samuel L. Jackson    Bruce Willis      1826188  107,928,762
# ..                 ...             ...          ...          ...
# 995      Patricia Neal     Buddy Ebsen       166544          NaN
# 996         James Dean   Carroll Baker        34075          NaN
# 997       Deborah Kerr      Donna Reed        43374   30,500,000
# 998      Walter Slezak  William Bendix        26471          NaN
# 999     Lucie Mannheim  Godfrey Tearle        51853          NaN
#
# [514 rows x 16 columns]

# %%
#You try to accomplish this with a Boolean mask! 
condition_1 = film_df["Released_Year"] >= 2000
film_df_2 = film_df[condition_1]
film_df_2
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ..                                                 ...
# 948  https://m.media-amazon.com/images/M/MV5BMTAxMD...
# 949  https://m.media-amazon.com/images/M/MV5BYjg5ZD...
# 950  https://m.media-amazon.com/images/M/MV5BYWFlY2...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 953  https://m.media-amazon.com/images/M/MV5BZTM2ZG...
#
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight           2008
# 5        The Lord of the Rings: The Return of the King           2003
# 8                                            Inception           2010
# 10   The Lord of the Rings: The Fellowship of the Ring           2001
# 13               The Lord of the Rings: The Two Towers           2002
# ..                                                 ...            ...
# 948                                         The Others           2001
# 949                                               Blow           2001
# 950                                 Enemy at the Gates           2001
# 951                                    Minority Report           2002
# 953                                    American Psycho           2000
#
#     Certificate  Runtime                      Genre  IMDB_Rating  \
# 2            UA  152 min       Action, Crime, Drama          9.0
# 5             U  201 min   Action, Adventure, Drama          8.9
# 8            UA  148 min  Action, Adventure, Sci-Fi          8.8
# 10            U  178 min   Action, Adventure, Drama          8.8
# 13           UA  179 min   Action, Adventure, Drama          8.7
# ..          ...      ...                        ...          ...
# 948       PG-13  101 min  Horror, Mystery, Thriller          7.6
# 949           R  124 min    Biography, Crime, Drama          7.6
# 950           A  131 min        Drama, History, War          7.6
# 951           A  145 min     Action, Crime, Mystery          7.6
# 953           A  101 min       Comedy, Crime, Drama          7.6
#
#                                               Overview  Meta_score  \
# 2    When the menace known as the Joker wreaks havo...        84.0
# 5    Gandalf and Aragorn lead the World of Men agai...        94.0
# 8    A thief who steals corporate secrets through t...        74.0
# 10   A meek Hobbit from the Shire and eight compani...        92.0
# 13   While Frodo and Sam edge closer to Mordor with...        87.0
# ..                                                 ...         ...
# 948  A woman who lives in her darkened old family h...        74.0
# 949  The story of how George Jung, along with the M...        52.0
# 950  A Russian and a German sniper play a game of c...        53.0
# 951  In a future where a special police unit is abl...        80.0
# 953  A wealthy New York City investment banking exe...        64.0
#
#                 Director              Star1                  Star2  \
# 2      Christopher Nolan     Christian Bale           Heath Ledger
# 5          Peter Jackson        Elijah Wood        Viggo Mortensen
# 8      Christopher Nolan  Leonardo DiCaprio   Joseph Gordon-Levitt
# 10         Peter Jackson        Elijah Wood           Ian McKellen
# 13         Peter Jackson        Elijah Wood           Ian McKellen
# ..                   ...                ...                    ...
# 948   Alejandro Amenábar      Nicole Kidman  Christopher Eccleston
# 949            Ted Demme        Johnny Depp          Penélope Cruz
# 950  Jean-Jacques Annaud           Jude Law              Ed Harris
# 951     Steven Spielberg         Tom Cruise          Colin Farrell
# 953          Mary Harron     Christian Bale         Justin Theroux
#
#                  Star3             Star4  No_of_Votes        Gross
# 2        Aaron Eckhart     Michael Caine      2303232  534,858,444
# 5         Ian McKellen     Orlando Bloom      1642758  377,845,905
# 8          Elliot Page      Ken Watanabe      2067042  292,576,195
# 10       Orlando Bloom         Sean Bean      1661481  315,544,750
# 13     Viggo Mortensen     Orlando Bloom      1485555  342,551,365
# ..                 ...               ...          ...          ...
# 948  Fionnula Flanagan      Alakina Mann       337651   96,522,687
# 949     Franka Potente  Rachel Griffiths       240714   52,990,775
# 950     Joseph Fiennes      Rachel Weisz       243729   51,401,758
# 951    Samantha Morton     Max von Sydow       508417  132,072,926
# 953         Josh Lucas         Bill Sage       490062   15,070,285
#
# [485 rows x 16 columns]

# %% [markdown]
# We could similarly choose to only look at movies from a particular decade:

# %%
column = film_df["Released_Year"]

film_df.loc[(column >= 1980) & (column <= 1989)]
# Out:
#                                            Poster_Link  \
# 16   https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 45   https://m.media-amazon.com/images/M/MV5BM2FhYj...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# 47   https://m.media-amazon.com/images/M/MV5BZmU0M2...
# 71   https://m.media-amazon.com/images/M/MV5BMGFkNW...
# ..                                                 ...
# 978  https://m.media-amazon.com/images/M/MV5BM2I1ZW...
# 979  https://m.media-amazon.com/images/M/MV5BZTllNW...
# 980  https://m.media-amazon.com/images/M/MV5BZmI5Yz...
# 981  https://m.media-amazon.com/images/M/MV5BNWQ4MG...
# 982  https://m.media-amazon.com/images/M/MV5BN2VlNj...
#
#                                        Series_Title  Released_Year  \
# 16   Star Wars: Episode V - The Empire Strikes Back           1980
# 45                            Nuovo Cinema Paradiso           1988
# 46                                   Hotaru no haka           1988
# 47                               Back to the Future           1985
# 71                      Once Upon a Time in America           1984
# ..                                              ...            ...
# 978                    Planes, Trains & Automobiles           1987
# 979                                   Lethal Weapon           1987
# 980                                    Blood Simple           1984
# 981                                  On Golden Pond           1981
# 982                                       Mad Max 2           1981
#
#     Certificate  Runtime                       Genre  IMDB_Rating  \
# 16           UA  124 min  Action, Adventure, Fantasy          8.7
# 45            U  155 min              Drama, Romance          8.5
# 46            U   89 min       Animation, Drama, War          8.5
# 47            U  116 min   Adventure, Comedy, Sci-Fi          8.5
# 71            A  229 min                Crime, Drama          8.4
# ..          ...      ...                         ...          ...
# 978           U   93 min               Comedy, Drama          7.6
# 979           A  109 min     Action, Crime, Thriller          7.6
# 980           A   99 min      Crime, Drama, Thriller          7.6
# 981          UA  109 min                       Drama          7.6
# 982           A   96 min   Action, Adventure, Sci-Fi          7.6
#
#                                               Overview  Meta_score  \
# 16   After the Rebels are brutally overpowered by t...        82.0
# 45   A filmmaker recalls his childhood when falling...        80.0
# 46   A young boy and his little sister struggle to ...        94.0
# 47   Marty McFly, a 17-year-old high school student...        87.0
# 71   A former Prohibition-era Jewish gangster retur...         NaN
# ..                                                 ...         ...
# 978  A man must struggle to travel home for Thanksg...        72.0
# 979  Two newly paired cops who are complete opposit...        68.0
# 980  The owner of a seedy small-town Texas bar disc...        82.0
# 981  Norman is a curmudgeon with an estranged relat...        68.0
# 982  In the post-apocalyptic Australian wasteland, ...        77.0
#
#                Director              Star1              Star2  \
# 16       Irvin Kershner        Mark Hamill      Harrison Ford
# 45   Giuseppe Tornatore    Philippe Noiret     Enzo Cannavale
# 46        Isao Takahata    Tsutomu Tatsumi    Ayano Shiraishi
# 47      Robert Zemeckis     Michael J. Fox  Christopher Lloyd
# 71         Sergio Leone     Robert De Niro        James Woods
# ..                  ...                ...                ...
# 978         John Hughes       Steve Martin         John Candy
# 979      Richard Donner         Mel Gibson       Danny Glover
# 980           Joel Coen         Ethan Coen          John Getz
# 981         Mark Rydell  Katharine Hepburn        Henry Fonda
# 982       George Miller         Mel Gibson       Bruce Spence
#
#                   Star3               Star4  No_of_Votes        Gross
# 16        Carrie Fisher  Billy Dee Williams      1159315  290,475,067
# 45     Antonella Attili         Isa Danieli       230763   11,990,401
# 46      Akemi Yamaguchi   Yoshiko Shinohara       235231          NaN
# 47         Lea Thompson      Crispin Glover      1058081  210,609,762
# 71   Elizabeth McGovern      Treat Williams       311365    5,321,508
# ..                  ...                 ...          ...          ...
# 978        Laila Robins      Michael McKean       124773   49,530,280
# 979          Gary Busey       Mitchell Ryan       236894   65,207,127
# 980   Frances McDormand          Dan Hedaya        87745    2,150,000
# 981          Jane Fonda         Doug McKeon        27650  119,285,432
# 982     Michael Preston          Max Phipps       166588   12,465,371
#
# [89 rows x 16 columns]

# %% [markdown]
# #### Section 3: Your turn!
#
# You are going to continue to use the IMDB dataset to answer the question *what is the average IMDB rating of the top 10 directors (by frequency) represented in the dataset?*
#
#   To answer this:
#
#   *   First, isolate the top 10 directors (as a hint: Alfred Hitchcock is number one)
#   *   Like we did above, convert that information into a dataframe.
#   *   Isolate the column with the directors in it and convert it into a list using [tolist()](https://www.geeksforgeeks.org/python-pandas-series-tolist/).
#   *   I want you to adapt the syntax that we learned above to strip PG out of the dataframe. You want to create a new copy of the dataframe and strip all directors out of it except those in the list we just created.
#   *   Finally, you can use groupby() to figure out what the average IMDB score is for those director's movies.

# %%
#finding top 10
top_10 = film_df["Director"].value_counts().head(10)

#dataframe conversion
top_10 = top_10.reset_index()
top_10.columns = ["Director", "Number of Movies"]

#isolate list
dir_list = top_10["Director"].tolist()

# %%
#isolating the top 10 directors
top_10_full = film_df[film_df["Director"].isin(dir_list) == True]

top_10_full
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 15   https://m.media-amazon.com/images/M/MV5BY2NkZj...
# ..                                                 ...
# 929  https://m.media-amazon.com/images/M/MV5BMjRjOT...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 988  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                            Series_Title  Released_Year Certificate  Runtime  \
# 2                       The Dark Knight           2008          UA  152 min
# 6                          Pulp Fiction           1994           A  154 min
# 7                      Schindler's List           1993           A  195 min
# 8                             Inception           2010          UA  148 min
# 15                           Goodfellas           1990           A  146 min
# ..                                  ...            ...         ...      ...
# 929                         Match Point           2005           R  124 min
# 951                     Minority Report           2002           A  145 min
# 988  Close Encounters of the Third Kind           1977           U  138 min
# 998                            Lifeboat           1944         NaN   97 min
# 999                        The 39 Steps           1935         NaN   86 min
#
#                          Genre  IMDB_Rating  \
# 2         Action, Crime, Drama          9.0
# 6                 Crime, Drama          8.9
# 7    Biography, Drama, History          8.9
# 8    Action, Adventure, Sci-Fi          8.8
# 15     Biography, Crime, Drama          8.7
# ..                         ...          ...
# 929   Drama, Romance, Thriller          7.6
# 951     Action, Crime, Mystery          7.6
# 988              Drama, Sci-Fi          7.6
# 998                 Drama, War          7.6
# 999   Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 2    When the menace known as the Joker wreaks havo...        84.0
# 6    The lives of two mob hitmen, a boxer, a gangst...        94.0
# 7    In German-occupied Poland during World War II,...        94.0
# 8    A thief who steals corporate secrets through t...        74.0
# 15   The story of Henry Hill and his life in the mo...        90.0
# ..                                                 ...         ...
# 929  At a turning point in his life, a former tenni...        72.0
# 951  In a future where a special police unit is abl...        80.0
# 988  Roy Neary, an electric lineman, watches how hi...        90.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#               Director               Star1                 Star2  \
# 2    Christopher Nolan      Christian Bale          Heath Ledger
# 6    Quentin Tarantino       John Travolta           Uma Thurman
# 7     Steven Spielberg         Liam Neeson         Ralph Fiennes
# 8    Christopher Nolan   Leonardo DiCaprio  Joseph Gordon-Levitt
# 15     Martin Scorsese      Robert De Niro            Ray Liotta
# ..                 ...                 ...                   ...
# 929        Woody Allen  Scarlett Johansson  Jonathan Rhys Meyers
# 951   Steven Spielberg          Tom Cruise         Colin Farrell
# 988   Steven Spielberg    Richard Dreyfuss     François Truffaut
# 998   Alfred Hitchcock   Tallulah Bankhead           John Hodiak
# 999   Alfred Hitchcock        Robert Donat     Madeleine Carroll
#
#                  Star3             Star4  No_of_Votes        Gross
# 2        Aaron Eckhart     Michael Caine      2303232  534,858,444
# 6    Samuel L. Jackson      Bruce Willis      1826188  107,928,762
# 7         Ben Kingsley  Caroline Goodall      1213505   96,898,818
# 8          Elliot Page      Ken Watanabe      2067042  292,576,195
# 15           Joe Pesci   Lorraine Bracco      1020727   46,836,394
# ..                 ...               ...          ...          ...
# 929     Emily Mortimer     Matthew Goode       206294   23,089,926
# 951    Samantha Morton     Max von Sydow       508417  132,072,926
# 988          Teri Garr    Melinda Dillon       184966  132,088,635
# 998      Walter Slezak    William Bendix        26471          NaN
# 999     Lucie Mannheim    Godfrey Tearle        51853          NaN
#
# [101 rows x 16 columns]

# %%
#finding average rating
avg_rating = top_10_full.groupby("Director")[["IMDB_Rating"]].mean()
avg_rating.sort_values(by="IMDB_Rating", ascending=False)
# Out:
#                    IMDB_Rating
# Director
# Christopher Nolan     8.462500
# Stanley Kubrick       8.233333
# Akira Kurosawa        8.220000
# Quentin Tarantino     8.175000
# Martin Scorsese       8.170000
# Billy Wilder          8.144444
# Steven Spielberg      8.030769
# Hayao Miyazaki        8.018182
# Alfred Hitchcock      8.007143
# Woody Allen           7.788889
