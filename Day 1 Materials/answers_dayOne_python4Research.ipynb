# %% [markdown]
# # Python for Researchers
#
# ## Day One Objectives
#
# * download and start working in VS Code
# * learn what a programming language is and how to 'read' and 'write' Python
# * learn some of the basic building blocks of Python
# * create a small program for re-writing file names
#
# ## Small Tips about using Jupyter Notebook in VSCode
#
# * to run a cell select 'shift' and 'enter' on your keyboard
# * you can hover between cells and select '+ markdown' to create a text cell or '+ code' to create a code cell
# * if you want to make a heading you can use #, ##, ###, or #### in front of the text
# * to move a cell up or down, you can select it and press either alt + up arrow or alt + down arrow

# %% [markdown]
# ## Section One : What is a Programming Language?
#
# A programming language is a set of instructions written by a programmer (you) for a computer. The computer interprets and executes those instructions.
#
# It can be helpful to lean into the idea of Python being 'interpreted.' On the one hand you are doing your best to write out code and on the other hand your computer is doing its best to read and execute it - but you're both used to speaking in very different ways!
#
# Consider the line of code below are the characters to the left and right the same? We can run it and see if Python interprets them that way:

# %%
"A " == "A"

# %% [markdown]
# **Why is the above statement false?**
#
# It is because Python encodes characters in many different ways in order to better translate them to your computer. Characters like numbers, letters, symbols and *even spaces* are translated in 'unicode' we can see that by using our 'ord' function that tells us the unicode of a character:

# %%
print(ord(" "))
print(ord("A"))

# %% [markdown]
# **Why does this matter?**
# A common error when learning to code is accidently leaving a space somewhere or not capitializing something correctly. Learning to code is like learning a language and there a many rules to learn in order to properly 'speak' it.
#
# For example, in the above code we surround the character A in qoutation marks. Why do we do that? Because we want Python to interpret that character as a letter, or, in Python terms a **string**.
#
# Below is a line of code with a 'string' and a sentence not in quotation marks:

# %%
"This is a sentence" == This is a sentence

# %% [markdown]
# When we run the code we get a **syntax error** which means there is something wrong with our coding grammar-in this case we are using incorrect formatting.
#
# We are going to revist these vocabularly terms (string, syntax) throughout the lesson, so don't worry if they haven't fully made sense yet.
#
# The think to keep in mind at this point is that while you may read the following as a sentance ```"this is a sentence"``` to Python it isn't a sentance at all, it is a string of characters with numerical meaning.
#
# Sometimes, working with Python can make you think that your computer is stupid, and should just *know* what you are trying to say, but that's not the way it works. Python has strict rules and isn't as flexible as other tools we may use all the time (like spellcheckers and autocorrect) so a large part of coding is learning to pay attention to the details.

# %% [markdown]
# ### Python Syntax
# Python Syntax is like the grammar of the language and what sets it apart from other coding languages.
#
# These are some of the basics of Python syntax. If you get a **syntax error** when running your code make sure you've double checked you've followed these rules!
#
# * Identation
#     * indentation in Python means something and helps the lanaguage determine the order and relationship between your lines of code
# * Data Types
#     * data types are specific objects in Python that are defined and used in specific ways the following are some data types:
#         * string = "string"
#         * integer = 8
#         * float = .08
#         * booleans = true, false
# * Comments
#     * comments are declared with a hashtag(#)
# * Parentheses
#     * parentheses group objects or call a function
# * End of lines are blank, or have a colon to note a new block of code
# * Keywords
#     * Python has a number of reserved words that cannot be used to name other objects and can only be used for their specific role
#     * Keywords are: False, wait, else, import, pass, None, break, except, In,  raise, True, class, finally, is, return, and, continue, for, lambda, try, as, def, from, nonlocal, while, assert, del, global, not, with, async, elif, if, or, yield

# %% [markdown]
# ### Reading Python
#
# Python was built intentionally to be a language that is a little more 'human readable.' Compare a statement in Python vs a statement in R:
#
# #### Python
#
# ```python
# files = ["reportDraft_2023-12-12.txt", "reportDraft_2024-1-23.txt", "reportDraft_2024-3-14.txt"]
#
# files = [file.replace("-","") for file in files]
#
# print(files)
# ```
# #### R
# ```r
# files <- c("reportDraft_2023-12-12.txt", "reportDraft_2024-1-23.txt", "reportDraft_2024-3-14.txt")
#
# files <- gsub("-", "", files)
#
# print(files)
# ```
#
# What differences between these examples do you notice? What makes one or the other more 'readable'?

# %% [markdown]
# ### Recognizing Python
#
# Understanding Python begins with being able to recognize the common building blocks used in the syntax. There are many types of objects in Python so being able to identify and know how they all work and work with one another is an important step to being able to write your own code or, read and use code you may find online or generate with a chat tool.
#
# We'll start by defining some of the basic ones and how to recognize them.

# %% [markdown]
# ### Variables and Data Types
#
# Variables are where you store information in Python. Variables are used so that you can quickly update, test, adjust and re-store information without constantly having to rewrite or remember the information itself.
#
# You can set variables to be many things, but today we are starting with 'strings', 'integers', and floats'
#
# Variables are created the following way:

# %%
variableName = "variableValue"

# %%
string = "This is a string"
integer = 9
decimalFloat = 0.8

print(string)
print(integer)
print(decimalFloat)

# %% [markdown]
# One thing to keep in mind, is that Python will read your code blocks from the top down, starting at line one and then working through each other line of code.
#
# It will also read your code in the order that you execute it, which is typically from the top down (like in this notebook). Keeping your code notebooks orgainized and in an executable order is an essential part of being a good, and conscientious coder.
#
# Let's play around with that idea:

# %%
print(string)

# %%
string = 'first'

# %%
string = 'second'

# %% [markdown]
# ### WRITE YOUR OWN
#
# Write your own string called 'name' with the value of your name!

# %%
# Create a string in this cell!

# %% [markdown]
# ### Operators
#
# Now that we've created variables we can update them!
#
# We are going to update our variables using another Python object called operators.
#
# Operators let us do equations: +, -, *, /, %
#
# Compare: ==, !=, <, >, <=, >=
#
# and assign (by combining a mathematical operator with a = sign): =, +=, -=, *=, /=, %=

# %%
string += ". It is all letters."
integer -= 2
decimalFloat *= 3

print(f"{string}\n{integer}\n{decimalFloat}")

# %% [markdown]
# ## Write your own!
#
# Solve the following problems in each of the code cells below.

# %%
# if I have the following items in my bag after shopping, how many total items have a bought? 

apples = 4
oranges = 5

# %%
# if I buy 2 apples and 1 orange, how much have I spent? What is the equation I would write in Python to solve
# the question?

apples = 1.50
oranges = 1.00

# %%
# create a variable 'hobby' and use that variable, along with your name variable from beofre, and the given
# clause variable to print the sentence: '[Name]'s favorite hobby is [hobby]' try and use an 'f' string AND try to use equations

clause = "'s favorite hobby is"

# %% [markdown]
# ### Lists
# Lists are a particular kind of object in Python that have their own syntax and additional functionalities for storing and updating the information in them.
#
# Lists look like:
#
# ```
# listName = ["listItemZero", "listItemOne", "listItemtwo"]
# ```
#
# There are lots of things we can do with lists which we'll cover in later lessons. For now, the two important things to note are that lists use brackets to surround list items and list items are separated by commas.

# %%
listOfStrings = ["zero", "one", "two"]
listOfIntegers = [0, 1, 2]
listOfTypes = [0.0, 0, "Zero"]

print(f"{listOfStrings}\n{listOfIntegers}\n{listOfTypes}")

# %% [markdown]
# An important note about lists is that they start at 'zero' so the first item in a list is at the '0' point in that list.
#
# The position of an item within an list is called its index and we can both use our lists' index to call items or check what the index of an item is.

# %%
characters = ["Essun", "Syanite", "Damaya"]

# %%
#print(characters[0])
print(characters.index("Syanite"))

# %% [markdown]
# In the first example we are using our lists' index to call the first item.
#
# In the second example we are using a **method** to perform a particular action, in this case to find out what is the index "zero" in our list

# %% [markdown]
# ## Indexing Strings
#
# Like lists, strings are also index-able. Every character in a string is assigned an index which means we can **slice** strings by referencing those indexes.
#
# Slicing a string looks like this:
#
# string = 'Cats like to play with string'
#
# string[6:11]
#
# The square brackets are a *slice* and are *indexing* the string to pull out the character's at those particular positions.

# %%
sentence = 'Cat sat on the mat'

sentence[:3]
sentence.index('sat')

# %% [markdown]
# ## WRITE YOU OWN
#
# How would you divide the following quote into two variables? One for Malcolm's line and one for Ellie's?
#
# You can just count the letters to try and find out where to slice, but try using the .index method to save you some time!

# %%
# Your code goes here! 

quote = "Malcolm: God create dinosuars, God destroys dinsaurs, God creates man, man destroys God, man creates dinosaurs. Ellie: Dinosaurs eat man, woman inherits the earth."

# %% [markdown]
# ## WRITE YOUR OWN
#
# Create a list with the following values:
#
# * October, 2017
# * November, 2018
# * October, 2020
# * December, 2021
# * January, 2017
#
# Write code the answer the rest of the questions.

# %%
# create your list here

dates = ['October, 2017', 'November, 2018', 'October, 2020', 'December, 2021', 'January, 2017']

# %%
# what is the index for October, 2020?

dates.index('October, 2017')
# Out:
# 0

# %%
# print the third item in the list. 

dates[2]
# Out:
# 'October, 2020'

# %%
# print, using indexing and slicing, just the year of the third list item.

dates[2][9:]
# Out:
# '2020'

# %% [markdown]
# ### Functions and Methods
# We've already used some functions and methods in this lesson. While they are not exactly the same thing, no one is going to get mad at you for calling a method a 'function' since it technically is a function, but it can only be used on certain objects. That's the big difference between them.
#
# Calling a function looks like:
#
# ```function(argument)```
#
# Using a method looks like:
# ```object.method(argument)```
#
# For functions, we use the function's name and then pass it an argument, often some type of object, that it will perform the function on.
#
# For methods, the object is attached to the method with a period '.' and the argument is placed in the parantheses. Often, the parantheses for methods will be left blank.

# %% [markdown]
# #### Built-In Functions
#
# [w3 schools has a list of built-in functions that you can explore.](https://www.w3schools.com/python/python_ref_functions.asp)
#
# Useful functions are below:
#
# * max() - returns the maximum value
# * min() - returns the minimum value
# * print() - prints the returned value
# * type() - returns the type of the object
# * len() - returns the len of the object

# %%
max(listOfStrings)
max(6, 10, 11)

len(listOfStrings)
len(string)

# %% [markdown]
# ### Common Methods
#
# **String Methods**
# * .upper() - converts letters to uppercase
# * .lower() - converst letters to lowercase
# * .count() - counts elements that match the given value
# * .index() - returns the index (location) of the given value
# * .join() - joins strings together
# * .replace() - replaces the first given value with the second given value
# * .split() - splits strings at the given value (index)
# * .strip() - strips leading and trailing whitespace
#
# **List Methods**
# * .append() - adds items to lists
# * .count() - counts elements that match the given value
# * .index() - returns the index of the given value
# * .pop() - removes an element based on the given value (index) and RETURNS the popped value
# * .remove() - removes the first item with the specified value (string)

# %%
#string method to capitalize letters
print(string.upper())
print(string)

# %%
#list methods
listOne = ['Orange', 'Apple', 'Grape']
listTwo = ['Apple', 'Grape']

# %%
listOne.append(listTwo)

# %% [markdown]
# ### Loops (Control Flow)
# Control flow objects include 'for' loops, 'while' loops, and 'if/elif' statements. We are not using 'if' statements today, but will in later sessions.
#
# Today we are learning 'for' loops:
# ```python
# for variable in iterable:
#   variable += 5
#   print(variable)
# ```
# There are also 'while' loops:
#
# ```python
# while object <= 7:
#   object += 1
#   print(object)
# ```

# %%
for item in fullList: 
    item.lower()
    print(item)

# %%
for item in listTwo: 
    listOne.append(item)
    print(item)
    print(listOne)

print(f'This is the final list:{listOne}')
# Out:
# Apple
# ['Orange', 'Apple', 'Grape', 'Apple']
# Grape
# ['Orange', 'Apple', 'Grape', 'Apple', 'Grape']
# This is the final list:['Orange', 'Apple', 'Grape', 'Apple', 'Grape']

# %% [markdown]
# ### Reading Comprehension with Python
#
# Let's revist our code from before that we compared with R's syntax. Now that we've gone over some of the different objects in Python, what can you identify in the below code?
#
# ```python
# files = ["reportDraft_2023-12-12.txt", "reportDraft_2024-1-23.txt", "reportDraft_2024-3-14.txt"]
#
# files = [file.replace("-","") for file in files]
#
# print(files)
# ```

# %% [markdown]
# ## What is this all used for?
# Strings, lists, and integers are the building blocks for starting to use Python for data analyses and processing.
#
# Many of the things you've learned today are important tools for processing data for analysis. Even if you aren't working with textual data, you are likely working with files or file paths which are strings and often need to be manipulated to make processing and orgainizing data files easier.
#
# For the last exercise of the day, take a list of given file names and clean it so that the returned list looks like this:
#
# * 'oct_10_1:22:00_carpenter.txt'
# * 'oct_11_1:22:00_carpenter.txt'
# * 'oct_11_2:33:00_hallenbeck.txt'
# * 'oct_12_11:59:00_gibson.txt'
# * 'oct_10_5:30:34_haller.txt'
#
# Do not change the index/order in the list, treat the strings as if they were literal files and you want to make sure the new name is applied to the correct file.
#
# Some hints:
# * start by trying to just get one file correct
# * then, once you know the steps, try putting them in a loop!
# * you may need to look up the documentation for the [.replace method to help](https://www.w3schools.com/python/ref_string_replace.asp)

# %%
files = ['698738945773589Carpenter/10-10-1_22_00-Carpenter,Ruth', '698738945773589Carpenter/10-11-1_22_00-Carpenter,Ruth', '59834759387593475Hallenbeck/10-11-2_33_00-Hallenbeck, Gregory', '3948759387538957Gibson/10-12-11_59_00-Gibson, Chelsea', '38937459834759387523Haller/10-10-5_30_34-Haller, Melissa']

# %%
files[0].index('/')
# Out:
# 24

# %%
files[0][25:]
# Out:
# '10-10-1_22_00-Carpenter,Ruth'

# %%
for file in files: 
    index = file.index('/') +1
    newfile = file[index:]
    print(newfile)
# Out:
# 10-10-1_22_00-Carpenter,Ruth
# 10-11-1_22_00-Carpenter,Ruth
# 10-11-2_33_00-Hallenbeck, Gregory
# 10-12-11_59_00-Gibson, Chelsea
# 10-10-5_30_34-Haller, Melissa
